# %%
# 각 알파벳의 출현 빈도에 대한 히스토그램 그려보기

# %%
# 각 알파벳의 출현 확률이 1/26이 아니다.
# 즉, 랜덤으로 생성된 알파벳이 아니라 정보를 담고 있다!

# %%
# 일반적인 영어 텍스트에서 알파벳의 확률분포는 어떻게 될까?

# %%
"""
(참고)
Substitution Cipher (단일치환 암호)
어떤 글자를 지정한 글자로 변환하는 방식의 암호 체계이다.

가능한 모든 경우의 수 = 26!

실제 영문에서 알파벳별 사용 빈도수와 암호문에서의 알파벳 출현 빈도를 대조하여
어떤 알파벳이 어떤 알파벳으로 암호화되었는지 통계와 확률을 기반으로 추론하여 암호체계를 뚫을 수 있다.
"""

# %%
unigram = {
    'a': 0.0575,
    'b': 0.0128,
    'c': 0.0263,
    'd': 0.0285,
    'e': 0.0913,
    'f': 0.0173,
    'g': 0.0133,
    'h': 0.0313,
    'i': 0.0599,
    'j': 0.0006,
    'k': 0.0084,
    'l': 0.0335,
    'm': 0.0235,
    'n': 0.0596,
    'o': 0.0689,
    'p': 0.0192,
    'q': 0.0008,
    'r': 0.0508,
    's': 0.0567,
    't': 0.0706,
    'u': 0.0334,
    'v': 0.0069,
    'w': 0.0119,
    'x': 0.0073,
    'y': 0.0164,
    'z': 0.0007,
    '-': 0.1928
}

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202024-07-29%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2012.10.16.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202024-07-29%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2012.10.16.png)

# %%
with open("Linux_FAQ_text.txt", 'r') as f:
    text = f.read()

# %%
len(text)

# %%
set(text)

# %%
text = text.lower()
set(text)

# %%
# 가장 많이 등장하는 알파벳: e
text.count('e')/len(text)

# %%
# 가장 적게 등장하는 알파벳: j
text.count('j')/len(text)

# %%
# conditional probability 계산하기

# P(u|q) vs P(s|q) 어떤 값이 더 클까

u_q = ((text.count('qu'))/(len(text)-1))/(text.count('q')/len(text))
s_q = ((text.count('qs'))/(len(text)-1))/(text.count('q')/len(text))

print(u_q, s_q)

# %%
# 딕셔너리 unigram의 형태처럼 각 알파벳 철자를 key로, 철자의 등장 확률을 value로 하는 딕셔너리 만들기

prob = {}

# %%
# (Homework) 위 그림에 있는 표의 알파벳별 확률과 Linux FAQ 텍스트의 알파벳별 확률을 각각 bar graph로 그리시오.

# dictionary의 key값들을 가져오는 방법: .keys()
# dictionary의 value값들을 가져오는 방법: .values()
# plt.bar()
